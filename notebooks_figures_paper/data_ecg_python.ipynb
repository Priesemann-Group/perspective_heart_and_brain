# %%
import numpy as np
import matplotlib.pyplot as plt

# wfdb
import wfdb

# %%
ecg = wfdb.rdsamp('/Users/johannes/git/projects/perspective_heart_and_brain/notebooks_figures_paper/data/Nemirko_PhysioNet_2022/6_Sinus_rhythm/frag/614_C_N_933_8s_frag')

# %%
print(ecg[0].shape)
print(ecg[0])
# Out:
# (721, 1)
# [[ 0.08 ]
#  [ 0.095]
#  [ 0.125]
#  [ 0.135]
#  [ 0.135]
#  [ 0.12 ]
#  [ 0.105]
#  [ 0.095]
#  [ 0.1  ]
#  [ 0.105]
#  [ 0.135]
#  [ 0.18 ]
#  [ 0.23 ]
#  [ 0.29 ]
#  [ 0.345]
#  [ 0.375]
#  [ 0.375]
#  [ 0.33 ]
#  [ 0.26 ]
#  [ 0.205]
#  [ 0.185]
#  [ 0.22 ]
#  [ 0.285]
#  [ 0.315]
#  [ 0.3  ]
#  [ 0.26 ]
#  [ 0.225]
#  [ 0.21 ]
#  [ 0.205]
#  [ 0.205]
#  [ 0.205]
#  [ 0.225]
#  [ 0.25 ]
#  [ 0.265]
#  [ 0.27 ]
#  [ 0.28 ]
#  [ 0.3  ]
#  [ 0.335]
#  [ 0.36 ]
#  [ 0.365]
#  [ 0.345]
#  [ 0.295]
#  [ 0.235]
#  [ 0.165]
#  [ 0.09 ]
#  [ 0.025]
#  [-0.01 ]
#  [-0.015]
#  [ 0.005]
#  [ 0.03 ]
#  [ 0.04 ]
#  [ 0.03 ]
#  [ 0.01 ]
#  [-0.01 ]
#  [-0.02 ]
#  [-0.025]
#  [-0.01 ]
#  [ 0.005]
#  [ 0.02 ]
#  [ 0.04 ]
#  [ 0.045]
#  [ 0.055]
#  [ 0.08 ]
#  [ 0.1  ]
#  [ 0.115]
#  [ 0.115]
#  [ 0.1  ]
#  [ 0.095]
#  [ 0.105]
#  [ 0.11 ]
#  [ 0.12 ]
#  [ 0.125]
#  [ 0.11 ]
#  [ 0.09 ]
#  [ 0.095]
#  [ 0.13 ]
#  [ 0.16 ]
#  [ 0.165]
#  [ 0.14 ]
#  [ 0.115]
#  [ 0.105]
#  [ 0.11 ]
# ...

# %%
# plot 
plt.plot(ecg[0])
plt.show()
